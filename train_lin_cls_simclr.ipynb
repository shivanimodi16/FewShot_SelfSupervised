# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, average_precision_score,confusion_matrix,classification_report


def mean_average_precision(y_true,y_preds,classes):
    mAP = 0

    for c in classes:
        pos = c
        y_true_bin,y_preds_bin = (y_true==pos)*1,(y_preds==pos)*1
        mAP+=average_precision_score(y_true_bin,y_preds_bin)

    mAP/=len(classes)
    return mAP


class TrainLinearClassifiersFS:
    def __init__(self,
                 X_train,
                 X_test,
                 y_train,
                 y_test,
                 cv,
                 benchmark_metric = 'acc'):
        
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test
        self.cv = cv
        
        self.benchmark_metric = benchmark_metric #Unused right now
        best_model = None
        self.results = {}
        self.classes = sorted(np.unique(self.y_train))
                
    def train_cv_lin_cls(self,
                           X_train: np.array,
                           y_train: np.array,
                           X_test: np.array,
                           y_test: np.array,
                           model: tuple,
                           param_grid: dict):

        sc = StandardScaler()

        pipe = Pipeline(steps = [('standardize',sc),
                                 model])

        param_grid = {f'{model[0]}__{k}':v for k,v in param_grid.items()}


        search = GridSearchCV(pipe, param_grid, n_jobs=-1,cv = self.cv,verbose=2)
        search.fit(X_train, y_train.flatten())
        print("Best parameter (CV score=%0.4f):" % search.best_score_)
        print(search.best_params_)

        best_estimator = search.best_estimator_

        print('Retraining with full training set with optimal hparams...')
        best_estimator.fit(X_train,y_train)

        y_preds = best_estimator.predict(X_test)

        acc = accuracy_score(y_test,y_preds)
        
        mAP = mean_average_precision(y_test,y_preds,self.classes)
        

        clf_report = classification_report(y_test, y_preds, labels=self.classes,output_dict = 'dict')
        
        
        
        clf_report_df = pd.DataFrame({k:v for k,v in clf_report.items() if k in map(str,self.classes)})
        
        print("Test set accuracy=%0.4f:" % acc)

        return best_estimator,acc,mAP,clf_report_df,clf_report

    def train_models(self,
                     X_train: np.array,
                     y_train: np.array,
                     X_test: np.array,
                     y_test: np.array,
                     models: dict):
        
        results = {}
        
        for k,v in models.items():

            print(f'Training {k}...')
            results[k] = {}

            model = (k,v['model'])
            param_grid = v['param_grid']

            (results[k]['best_estimator'],
             results[k]['test_acc'],
             results[k]['test_ap'],
            results[k]['clf_report_df'],
            results[k]['clf_report']) = self.train_cv_lin_cls(X_train,
                                                              y_train,
                                                              X_test,
                                                              y_test,
                                                              model,
                                                              param_grid)

        best_model_name = max(results, key=lambda v: results[v].get('test_acc'))
        best_model = results[best_model_name]

        return best_model,results



    
    def sample_n_per_class(self,X,y,n,shuffle = True):
        sampled_ids = []
        classes = np.unique(y)
        for c in classes:
            c_ids = np.where(y.flatten()==c)[0]
            sampled_ids.extend(list(np.random.choice(c_ids,size=n,replace=False)))

        if shuffle:
            np.random.shuffle(sampled_ids)

        return X[sampled_ids],y[sampled_ids]
    
    def train_few_shot_models(self,
                              X_train: np.array,
                              y_train: np.array,
                              X_test: np.array,
                              y_test: np.array,
                              models: dict,
                              ns: list,
                              repeats: int = 5):
        
        for trial in range(repeats):
            
            self.results[trial] = {}
            
            for n in ns:
                print(f'Training with {n} observations per class...')

                X_train_fs, y_train_fs = self.sample_n_per_class(X_train,y_train,n)

                best_model,results = self.train_models(X_train_fs,
                                                       y_train_fs,
                                                       X_test,
                                                       y_test,
                                                       models)

                self.results[trial][n] = {'best_model':best_model,'results':results}

        return self.results

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression

# %%
X_train = np.load(f'X_train.npy')
X_test = np.load(f'X_test.npy')

y_train = np.load(f'y_train.npy')
y_test = np.load(f'y_test.npy')

# %%
svm = LinearSVC(max_iter=5000,
                dual=False,
                class_weight='balanced',
                verbose=2
               )

lr = LogisticRegression(multi_class = 'multinomial',max_iter=5000)


models = {
         'SVM':
          {'model':svm,
          'param_grid':{'C':list(2**np.arange(-19,-3,1,dtype=float))+list(10**np.arange(-7,2,1,dtype=float))}
          },
          
          'LR':
          {'model':lr,
           'param_grid':{'C':10**np.linspace(-6,6,40)}
          }
         }

cv = 3
ns = [
      3,
      4,
      8,
      16,
      32,
      96
    ]
repeats = 5

# %%
# %%time

tlc = TrainLinearClassifiersFS(X_train,
                                 X_test,
                                 y_train,
                                 y_test,cv)
results = tlc.train_few_shot_models(X_train,
                                   y_train.flatten(),
                                   X_test,
                                   y_test.flatten(),
                                   models,
                                   ns,
                                   repeats = 5)
print(results)
# Out:
# Training with 3 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.2667):
# {'SVM__C': 1.9073486328125e-06}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2178:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3333):
# {'LR__C': 0.08376776400682924}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.2628:
# Training with 4 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4267):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3116:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3773):
# {'LR__C': 412.46263829013645}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3014:
# Training with 8 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3371):
# {'SVM__C': 0.001953125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3284:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.2877):
# {'LR__C': 0.08376776400682924}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3440:
# Training with 16 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4000):
# {'SVM__C': 0.0078125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4068:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4311):
# {'LR__C': 1.4251026703029992}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4114:
# Training with 32 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4345):
# {'SVM__C': 0.0001220703125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4171:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4406):
# {'LR__C': 0.002424462017082331}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4384:
# Training with 96 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4677):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4967:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4625):
# {'LR__C': 0.01}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.5002:
# Training with 3 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3333):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2906:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4000):
# {'LR__C': 837.6776400682925}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.2913:
# Training with 4 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3004):
# {'SVM__C': 1.9073486328125e-06}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3000:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.2271):
# {'LR__C': 0.08376776400682924}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3229:
# Training with 8 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3856):
# {'SVM__C': 0.0078125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3654:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3870):
# {'LR__C': 0.08376776400682924}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3615:
# Training with 16 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3747):
# {'SVM__C': 0.00048828125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4146:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3812):
# {'LR__C': 0.01}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4124:
# Training with 32 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4125):
# {'SVM__C': 0.00390625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4458:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4186):
# {'LR__C': 0.17012542798525893}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4299:
# Training with 96 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.5135):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.5061:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.5240):
# {'LR__C': 0.01}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.5119:
# Training with 3 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3000):
# {'SVM__C': 3.0517578125e-05}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2969:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3333):
# {'LR__C': 0.002424462017082331}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3138:
# Training with 4 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.2747):
# {'SVM__C': 1.9073486328125e-06}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3155:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.2491):
# {'LR__C': 0.7017038286703837}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3362:
# Training with 8 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.2877):
# {'SVM__C': 0.000244140625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3538:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.2882):
# {'LR__C': 0.001193776641714437}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3481:
# Training with 16 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3559):
# {'SVM__C': 0.0001220703125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3928:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3751):
# {'LR__C': 0.004923882631706742}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4274:
# Training with 32 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4408):
# {'SVM__C': 0.00390625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4365:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4471):
# {'LR__C': 0.041246263829013564}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4514:
# Training with 96 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4656):
# {'SVM__C': 0.0078125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.5053:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4531):
# {'LR__C': 0.041246263829013564}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.5028:
# Training with 3 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3333):
# {'SVM__C': 0.0625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2594:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.2667):
# {'LR__C': 0.01}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.2651:
# Training with 4 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4249):
# {'SVM__C': 0.0078125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2678:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4249):
# {'LR__C': 1701.2542798525926}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.2725:
# Training with 8 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3495):
# {'SVM__C': 1.9073486328125e-06}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.2924:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3865):
# {'LR__C': 3455.1072945922183}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3261:
# Training with 16 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4436):
# {'SVM__C': 0.001953125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4347:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4504):
# {'LR__C': 0.004923882631706742}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4294:
# Training with 32 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4002):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4463:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3874):
# {'LR__C': 0.041246263829013564}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4544:
# Training with 96 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4917):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4952:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4854):
# {'LR__C': 0.004923882631706742}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4826:
# Training with 3 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3667):
# {'SVM__C': 1.9073486328125e-06}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3507:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4667):
# {'LR__C': 0.01}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3381:
# Training with 4 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.2253):
# {'SVM__C': 0.03125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3142:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.1996):
# {'LR__C': 0.17012542798525893}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3063:
# Training with 8 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3984):
# {'SVM__C': 0.000244140625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3757:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3609):
# {'LR__C': 0.004923882631706742}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3603:
# Training with 16 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3442):
# {'SVM__C': 0.01}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.3802:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3750):
# {'LR__C': 0.08376776400682924}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.3878:
# Training with 32 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.3874):
# {'SVM__C': 0.0009765625}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.4498:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.3906):
# {'LR__C': 0.041246263829013564}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.4544:
# Training with 96 observations per class...
# Training SVM...
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LibLinear]Best parameter (CV score=0.4781):
# {'SVM__C': 0.001953125}
# Retraining with full training set with optimal hparams...
# [LibLinear]Test set accuracy=0.5110:
# Training LR...
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# Best parameter (CV score=0.4833):
# {'LR__C': 0.02030917620904739}
# Retraining with full training set with optimal hparams...
# Test set accuracy=0.5119:
# {0: {3: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.08376776400682924, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.2628, 'test_ap': 0.1468134700113645, 'clf_report_df':                      0            1  ...            8            9
# precision     0.282987     0.265808  ...     0.314433     0.371590
# recall        0.504000     0.227000  ...     0.488000     0.395000
# f1-score      0.362460     0.244876  ...     0.382445     0.382937
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.28298708590679394, 'recall': 0.504, 'f1-score': 0.3624595469255663, 'support': 1000}, '1': {'precision': 0.265807962529274, 'recall': 0.227, 'f1-score': 0.24487594390507011, 'support': 1000}, '2': {'precision': 0.15628192032686414, 'recall': 0.153, 'f1-score': 0.15462354724608388, 'support': 1000}, '3': {'precision': 0.16258351893095768, 'recall': 0.146, 'f1-score': 0.15384615384615383, 'support': 1000}, '4': {'precision': 0.21957340025094102, 'recall': 0.175, 'f1-score': 0.19476905954368393, 'support': 1000}, '5': {'precision': 0.22811671087533156, 'recall': 0.172, 'f1-score': 0.1961231470923603, 'support': 1000}, '6': {'precision': 0.2777129521586931, 'recall': 0.238, 'f1-score': 0.25632740980075386, 'support': 1000}, '7': {'precision': 0.27956989247311825, 'recall': 0.13, 'f1-score': 0.1774744027303754, 'support': 1000}, '8': {'precision': 0.31443298969072164, 'recall': 0.488, 'f1-score': 0.3824451410658307, 'support': 1000}, '9': {'precision': 0.3715898400752587, 'recall': 0.395, 'f1-score': 0.3829374697043142, 'support': 1000}, 'accuracy': 0.2628, 'macro avg': {'precision': 0.25586562732179546, 'recall': 0.26280000000000003, 'f1-score': 0.25058818218601925, 'support': 10000}, 'weighted avg': {'precision': 0.25586562732179535, 'recall': 0.2628, 'f1-score': 0.25058818218601925, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=1.9073486328125e-06, class_weight='balanced',
#                            dual=False, max_iter=5000, verbose=2))]), 'test_acc': 0.2178, 'test_ap': 0.13151622082602837, 'clf_report_df':                      0            1  ...            8            9
# precision     0.320606     0.261182  ...     0.283688     0.155598
# recall        0.487000     0.473000  ...     0.520000     0.082000
# f1-score      0.386661     0.336535  ...     0.367102     0.107400
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.3206056616194865, 'recall': 0.487, 'f1-score': 0.3866613735609369, 'support': 1000}, '1': {'precision': 0.26118166758696854, 'recall': 0.473, 'f1-score': 0.3365350409107079, 'support': 1000}, '2': {'precision': 0.13735632183908045, 'recall': 0.239, 'f1-score': 0.17445255474452553, 'support': 1000}, '3': {'precision': 0.1288445552784705, 'recall': 0.155, 'f1-score': 0.14071720381298228, 'support': 1000}, '4': {'precision': 0.19904076738609114, 'recall': 0.083, 'f1-score': 0.11714890613973183, 'support': 1000}, '5': {'precision': 0.23469387755102042, 'recall': 0.023, 'f1-score': 0.04189435336976321, 'support': 1000}, '6': {'precision': 0.1083086053412463, 'recall': 0.073, 'f1-score': 0.08721624850657109, 'support': 1000}, '7': {'precision': 0.24157303370786518, 'recall': 0.043, 'f1-score': 0.0730050933786078, 'support': 1000}, '8': {'precision': 0.28368794326241137, 'recall': 0.52, 'f1-score': 0.36710201200141196, 'support': 1000}, '9': {'precision': 0.1555977229601518, 'recall': 0.082, 'f1-score': 0.1074001309757695, 'support': 1000}, 'accuracy': 0.2178, 'macro avg': {'precision': 0.20708901565327925, 'recall': 0.2178, 'f1-score': 0.18321329174010081, 'support': 10000}, 'weighted avg': {'precision': 0.20708901565327925, 'recall': 0.2178, 'f1-score': 0.18321329174010084, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.08376776400682924, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.2628, 'test_ap': 0.1468134700113645, 'clf_report_df':                      0            1  ...            8            9
# precision     0.282987     0.265808  ...     0.314433     0.371590
# recall        0.504000     0.227000  ...     0.488000     0.395000
# f1-score      0.362460     0.244876  ...     0.382445     0.382937
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.28298708590679394, 'recall': 0.504, 'f1-score': 0.3624595469255663, 'support': 1000}, '1': {'precision': 0.265807962529274, 'recall': 0.227, 'f1-score': 0.24487594390507011, 'support': 1000}, '2': {'precision': 0.15628192032686414, 'recall': 0.153, 'f1-score': 0.15462354724608388, 'support': 1000}, '3': {'precision': 0.16258351893095768, 'recall': 0.146, 'f1-score': 0.15384615384615383, 'support': 1000}, '4': {'precision': 0.21957340025094102, 'recall': 0.175, 'f1-score': 0.19476905954368393, 'support': 1000}, '5': {'precision': 0.22811671087533156, 'recall': 0.172, 'f1-score': 0.1961231470923603, 'support': 1000}, '6': {'precision': 0.2777129521586931, 'recall': 0.238, 'f1-score': 0.25632740980075386, 'support': 1000}, '7': {'precision': 0.27956989247311825, 'recall': 0.13, 'f1-score': 0.1774744027303754, 'support': 1000}, '8': {'precision': 0.31443298969072164, 'recall': 0.488, 'f1-score': 0.3824451410658307, 'support': 1000}, '9': {'precision': 0.3715898400752587, 'recall': 0.395, 'f1-score': 0.3829374697043142, 'support': 1000}, 'accuracy': 0.2628, 'macro avg': {'precision': 0.25586562732179546, 'recall': 0.26280000000000003, 'f1-score': 0.25058818218601925, 'support': 10000}, 'weighted avg': {'precision': 0.25586562732179535, 'recall': 0.2628, 'f1-score': 0.25058818218601925, 'support': 10000}}}}}, 4: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0009765625, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.3116, 'test_ap': 0.17370432074975806, 'clf_report_df':                      0            1  ...            8            9
# precision     0.262974     0.415842  ...     0.308861     0.460897
# recall        0.451000     0.294000  ...     0.122000     0.442000
# f1-score      0.332228     0.344464  ...     0.174910     0.451251
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.2629737609329446, 'recall': 0.451, 'f1-score': 0.33222836095764274, 'support': 1000}, '1': {'precision': 0.4158415841584158, 'recall': 0.294, 'f1-score': 0.34446397188049205, 'support': 1000}, '2': {'precision': 0.21372719374456994, 'recall': 0.246, 'f1-score': 0.2287308228730823, 'support': 1000}, '3': {'precision': 0.1664190193164933, 'recall': 0.112, 'f1-score': 0.13389121338912133, 'support': 1000}, '4': {'precision': 0.2057877813504823, 'recall': 0.064, 'f1-score': 0.09763539282990083, 'support': 1000}, '5': {'precision': 0.2678132678132678, 'recall': 0.327, 'f1-score': 0.29446195407474113, 'support': 1000}, '6': {'precision': 0.40717299578059074, 'recall': 0.579, 'f1-score': 0.47811725846407926, 'support': 1000}, '7': {'precision': 0.3312586445366528, 'recall': 0.479, 'f1-score': 0.39165985282093213, 'support': 1000}, '8': {'precision': 0.30886075949367087, 'recall': 0.122, 'f1-score': 0.17491039426523297, 'support': 1000}, '9': {'precision': 0.4608967674661105, 'recall': 0.442, 'f1-score': 0.45125063808065335, 'support': 1000}, 'accuracy': 0.3116, 'macro avg': {'precision': 0.3040751774593199, 'recall': 0.3116, 'f1-score': 0.2927349859635878, 'support': 10000}, 'weighted avg': {'precision': 0.30407517745931983, 'recall': 0.3116, 'f1-score': 0.29273498596358777, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0009765625, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.3116, 'test_ap': 0.17370432074975806, 'clf_report_df':                      0            1  ...            8            9
# precision     0.262974     0.415842  ...     0.308861     0.460897
# recall        0.451000     0.294000  ...     0.122000     0.442000
# f1-score      0.332228     0.344464  ...     0.174910     0.451251
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.2629737609329446, 'recall': 0.451, 'f1-score': 0.33222836095764274, 'support': 1000}, '1': {'precision': 0.4158415841584158, 'recall': 0.294, 'f1-score': 0.34446397188049205, 'support': 1000}, '2': {'precision': 0.21372719374456994, 'recall': 0.246, 'f1-score': 0.2287308228730823, 'support': 1000}, '3': {'precision': 0.1664190193164933, 'recall': 0.112, 'f1-score': 0.13389121338912133, 'support': 1000}, '4': {'precision': 0.2057877813504823, 'recall': 0.064, 'f1-score': 0.09763539282990083, 'support': 1000}, '5': {'precision': 0.2678132678132678, 'recall': 0.327, 'f1-score': 0.29446195407474113, 'support': 1000}, '6': {'precision': 0.40717299578059074, 'recall': 0.579, 'f1-score': 0.47811725846407926, 'support': 1000}, '7': {'precision': 0.3312586445366528, 'recall': 0.479, 'f1-score': 0.39165985282093213, 'support': 1000}, '8': {'precision': 0.30886075949367087, 'recall': 0.122, 'f1-score': 0.17491039426523297, 'support': 1000}, '9': {'precision': 0.4608967674661105, 'recall': 0.442, 'f1-score': 0.45125063808065335, 'support': 1000}, 'accuracy': 0.3116, 'macro avg': {'precision': 0.3040751774593199, 'recall': 0.3116, 'f1-score': 0.2927349859635878, 'support': 10000}, 'weighted avg': {'precision': 0.30407517745931983, 'recall': 0.3116, 'f1-score': 0.29273498596358777, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=412.46263829013645, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.3014, 'test_ap': 0.17116543604550866, 'clf_report_df':                      0            1  ...            8            9
# precision     0.264933     0.361528  ...     0.286924     0.478022
# recall        0.275000     0.265000  ...     0.305000     0.348000
# f1-score      0.269872     0.305828  ...     0.295686     0.402778
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.2649325626204239, 'recall': 0.275, 'f1-score': 0.2698724239450442, 'support': 1000}, '1': {'precision': 0.3615279672578445, 'recall': 0.265, 'f1-score': 0.3058280438545874, 'support': 1000}, '2': {'precision': 0.2033112582781457, 'recall': 0.307, 'f1-score': 0.2446215139442231, 'support': 1000}, '3': {'precision': 0.17245119305856832, 'recall': 0.159, 'f1-score': 0.16545265348595214, 'support': 1000}, '4': {'precision': 0.3217391304347826, 'recall': 0.111, 'f1-score': 0.1650557620817844, 'support': 1000}, '5': {'precision': 0.22113365990202938, 'recall': 0.316, 'f1-score': 0.26018937834499795, 'support': 1000}, '6': {'precision': 0.4965437788018433, 'recall': 0.431, 'f1-score': 0.46145610278372595, 'support': 1000}, '7': {'precision': 0.36436950146627567, 'recall': 0.497, 'f1-score': 0.42047377326565144, 'support': 1000}, '8': {'precision': 0.2869238005644403, 'recall': 0.305, 'f1-score': 0.2956858943286476, 'support': 1000}, '9': {'precision': 0.47802197802197804, 'recall': 0.348, 'f1-score': 0.4027777777777778, 'support': 1000}, 'accuracy': 0.3014, 'macro avg': {'precision': 0.3170954830406332, 'recall': 0.3014, 'f1-score': 0.2991413323812392, 'support': 10000}, 'weighted avg': {'precision': 0.3170954830406331, 'recall': 0.3014, 'f1-score': 0.2991413323812392, 'support': 10000}}}}}, 8: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.08376776400682924, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.344, 'test_ap': 0.19480141535820375, 'clf_report_df':                      0            1  ...            8            9
# precision     0.259222     0.337573  ...     0.435194     0.474728
# recall        0.260000     0.345000  ...     0.460000     0.742000
# f1-score      0.259611     0.341246  ...     0.447253     0.579009
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.259222333000997, 'recall': 0.26, 'f1-score': 0.2596105841238142, 'support': 1000}, '1': {'precision': 0.337573385518591, 'recall': 0.345, 'f1-score': 0.34124629080118696, 'support': 1000}, '2': {'precision': 0.1855123674911661, 'recall': 0.105, 'f1-score': 0.13409961685823754, 'support': 1000}, '3': {'precision': 0.1946607341490545, 'recall': 0.175, 'f1-score': 0.18430753027909424, 'support': 1000}, '4': {'precision': 0.22732491389207807, 'recall': 0.198, 'f1-score': 0.21165152324959918, 'support': 1000}, '5': {'precision': 0.2810750279955207, 'recall': 0.251, 'f1-score': 0.2651875330163761, 'support': 1000}, '6': {'precision': 0.4540084388185654, 'recall': 0.538, 'f1-score': 0.4924485125858123, 'support': 1000}, '7': {'precision': 0.3889479277364506, 'recall': 0.366, 'f1-score': 0.37712519319938176, 'support': 1000}, '8': {'precision': 0.43519394512771997, 'recall': 0.46, 'f1-score': 0.44725328147788046, 'support': 1000}, '9': {'precision': 0.47472808701215613, 'recall': 0.742, 'f1-score': 0.5790089738587593, 'support': 1000}, 'accuracy': 0.344, 'macro avg': {'precision': 0.3238247160742299, 'recall': 0.344, 'f1-score': 0.3291939039450142, 'support': 10000}, 'weighted avg': {'precision': 0.32382471607422997, 'recall': 0.344, 'f1-score': 0.32919390394501424, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.001953125, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.3284, 'test_ap': 0.17910009532186508, 'clf_report_df':                      0            1  ...            8            9
# precision     0.251167     0.306064  ...     0.376313     0.376409
# recall        0.269000     0.318000  ...     0.394000     0.868000
# f1-score      0.259778     0.311918  ...     0.384954     0.525106
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.2511671335200747, 'recall': 0.269, 'f1-score': 0.25977788507967164, 'support': 1000}, '1': {'precision': 0.3060635226179018, 'recall': 0.318, 'f1-score': 0.3119176066699362, 'support': 1000}, '2': {'precision': 0.20192307692307693, 'recall': 0.021, 'f1-score': 0.03804347826086957, 'support': 1000}, '3': {'precision': 0.2540106951871658, 'recall': 0.19, 'f1-score': 0.21739130434782608, 'support': 1000}, '4': {'precision': 0.21807228915662652, 'recall': 0.181, 'f1-score': 0.19781420765027324, 'support': 1000}, '5': {'precision': 0.2905405405405405, 'recall': 0.215, 'f1-score': 0.24712643678160917, 'support': 1000}, '6': {'precision': 0.4041316978695933, 'recall': 0.626, 'f1-score': 0.4911730090231463, 'support': 1000}, '7': {'precision': 0.3568904593639576, 'recall': 0.202, 'f1-score': 0.25798212005108556, 'support': 1000}, '8': {'precision': 0.3763132760267431, 'recall': 0.394, 'f1-score': 0.3849535906204201, 'support': 1000}, '9': {'precision': 0.3764093668690373, 'recall': 0.868, 'f1-score': 0.5251058681185723, 'support': 1000}, 'accuracy': 0.3284, 'macro avg': {'precision': 0.3035522058074717, 'recall': 0.3284, 'f1-score': 0.293128550660341, 'support': 10000}, 'weighted avg': {'precision': 0.3035522058074717, 'recall': 0.3284, 'f1-score': 0.293128550660341, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.08376776400682924, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.344, 'test_ap': 0.19480141535820375, 'clf_report_df':                      0            1  ...            8            9
# precision     0.259222     0.337573  ...     0.435194     0.474728
# recall        0.260000     0.345000  ...     0.460000     0.742000
# f1-score      0.259611     0.341246  ...     0.447253     0.579009
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.259222333000997, 'recall': 0.26, 'f1-score': 0.2596105841238142, 'support': 1000}, '1': {'precision': 0.337573385518591, 'recall': 0.345, 'f1-score': 0.34124629080118696, 'support': 1000}, '2': {'precision': 0.1855123674911661, 'recall': 0.105, 'f1-score': 0.13409961685823754, 'support': 1000}, '3': {'precision': 0.1946607341490545, 'recall': 0.175, 'f1-score': 0.18430753027909424, 'support': 1000}, '4': {'precision': 0.22732491389207807, 'recall': 0.198, 'f1-score': 0.21165152324959918, 'support': 1000}, '5': {'precision': 0.2810750279955207, 'recall': 0.251, 'f1-score': 0.2651875330163761, 'support': 1000}, '6': {'precision': 0.4540084388185654, 'recall': 0.538, 'f1-score': 0.4924485125858123, 'support': 1000}, '7': {'precision': 0.3889479277364506, 'recall': 0.366, 'f1-score': 0.37712519319938176, 'support': 1000}, '8': {'precision': 0.43519394512771997, 'recall': 0.46, 'f1-score': 0.44725328147788046, 'support': 1000}, '9': {'precision': 0.47472808701215613, 'recall': 0.742, 'f1-score': 0.5790089738587593, 'support': 1000}, 'accuracy': 0.344, 'macro avg': {'precision': 0.3238247160742299, 'recall': 0.344, 'f1-score': 0.3291939039450142, 'support': 10000}, 'weighted avg': {'precision': 0.32382471607422997, 'recall': 0.344, 'f1-score': 0.32919390394501424, 'support': 10000}}}}}, 16: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=1.4251026703029992, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4114, 'test_ap': 0.23357779381668475, 'clf_report_df':                      0            1  ...            8            9
# precision     0.341040     0.406830  ...     0.451411     0.495422
# recall        0.413000     0.548000  ...     0.432000     0.487000
# f1-score      0.373587     0.466979  ...     0.441492     0.491175
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.34104046242774566, 'recall': 0.413, 'f1-score': 0.3735866123925825, 'support': 1000}, '1': {'precision': 0.40682999257609503, 'recall': 0.548, 'f1-score': 0.46697912228376653, 'support': 1000}, '2': {'precision': 0.2972972972972973, 'recall': 0.341, 'f1-score': 0.3176525384257103, 'support': 1000}, '3': {'precision': 0.339142091152815, 'recall': 0.253, 'f1-score': 0.2898052691867125, 'support': 1000}, '4': {'precision': 0.3864836325237592, 'recall': 0.366, 'f1-score': 0.37596302003081666, 'support': 1000}, '5': {'precision': 0.39766081871345027, 'recall': 0.34, 'f1-score': 0.3665768194070081, 'support': 1000}, '6': {'precision': 0.5024248302618817, 'recall': 0.518, 'f1-score': 0.5100935499753816, 'support': 1000}, '7': {'precision': 0.5360824742268041, 'recall': 0.416, 'f1-score': 0.4684684684684684, 'support': 1000}, '8': {'precision': 0.45141065830721006, 'recall': 0.432, 'f1-score': 0.44149207971384774, 'support': 1000}, '9': {'precision': 0.49542217700915564, 'recall': 0.487, 'f1-score': 0.49117498739283905, 'support': 1000}, 'accuracy': 0.4114, 'macro avg': {'precision': 0.41537944344962147, 'recall': 0.4114, 'f1-score': 0.41017924672771333, 'support': 10000}, 'weighted avg': {'precision': 0.41537944344962136, 'recall': 0.4114, 'f1-score': 0.41017924672771333, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0078125, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.4068, 'test_ap': 0.2300716349523489, 'clf_report_df':                      0            1  ...            8            9
# precision     0.319363     0.431433  ...     0.445570     0.510921
# recall        0.381000     0.560000  ...     0.352000     0.538000
# f1-score      0.347469     0.487380  ...     0.393296     0.524111
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.3193629505448449, 'recall': 0.381, 'f1-score': 0.347469220246238, 'support': 1000}, '1': {'precision': 0.43143297380585516, 'recall': 0.56, 'f1-score': 0.4873803307223673, 'support': 1000}, '2': {'precision': 0.29785604900459417, 'recall': 0.389, 'f1-score': 0.3373807458803122, 'support': 1000}, '3': {'precision': 0.33925049309664695, 'recall': 0.172, 'f1-score': 0.2282680822826808, 'support': 1000}, '4': {'precision': 0.3704819277108434, 'recall': 0.369, 'f1-score': 0.36973947895791587, 'support': 1000}, '5': {'precision': 0.40213523131672596, 'recall': 0.339, 'f1-score': 0.36787845903418337, 'support': 1000}, '6': {'precision': 0.4783319705641864, 'recall': 0.585, 'f1-score': 0.5263157894736842, 'support': 1000}, '7': {'precision': 0.48419721871049304, 'recall': 0.383, 'f1-score': 0.4276940256839754, 'support': 1000}, '8': {'precision': 0.44556962025316454, 'recall': 0.352, 'f1-score': 0.39329608938547483, 'support': 1000}, '9': {'precision': 0.5109211775878443, 'recall': 0.538, 'f1-score': 0.5241110569897711, 'support': 1000}, 'accuracy': 0.4068, 'macro avg': {'precision': 0.4079539612595199, 'recall': 0.40679999999999994, 'f1-score': 0.4009533278656603, 'support': 10000}, 'weighted avg': {'precision': 0.4079539612595199, 'recall': 0.4068, 'f1-score': 0.40095332786566035, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=1.4251026703029992, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4114, 'test_ap': 0.23357779381668475, 'clf_report_df':                      0            1  ...            8            9
# precision     0.341040     0.406830  ...     0.451411     0.495422
# recall        0.413000     0.548000  ...     0.432000     0.487000
# f1-score      0.373587     0.466979  ...     0.441492     0.491175
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.34104046242774566, 'recall': 0.413, 'f1-score': 0.3735866123925825, 'support': 1000}, '1': {'precision': 0.40682999257609503, 'recall': 0.548, 'f1-score': 0.46697912228376653, 'support': 1000}, '2': {'precision': 0.2972972972972973, 'recall': 0.341, 'f1-score': 0.3176525384257103, 'support': 1000}, '3': {'precision': 0.339142091152815, 'recall': 0.253, 'f1-score': 0.2898052691867125, 'support': 1000}, '4': {'precision': 0.3864836325237592, 'recall': 0.366, 'f1-score': 0.37596302003081666, 'support': 1000}, '5': {'precision': 0.39766081871345027, 'recall': 0.34, 'f1-score': 0.3665768194070081, 'support': 1000}, '6': {'precision': 0.5024248302618817, 'recall': 0.518, 'f1-score': 0.5100935499753816, 'support': 1000}, '7': {'precision': 0.5360824742268041, 'recall': 0.416, 'f1-score': 0.4684684684684684, 'support': 1000}, '8': {'precision': 0.45141065830721006, 'recall': 0.432, 'f1-score': 0.44149207971384774, 'support': 1000}, '9': {'precision': 0.49542217700915564, 'recall': 0.487, 'f1-score': 0.49117498739283905, 'support': 1000}, 'accuracy': 0.4114, 'macro avg': {'precision': 0.41537944344962147, 'recall': 0.4114, 'f1-score': 0.41017924672771333, 'support': 10000}, 'weighted avg': {'precision': 0.41537944344962136, 'recall': 0.4114, 'f1-score': 0.41017924672771333, 'support': 10000}}}}}, 32: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.002424462017082331, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4384, 'test_ap': 0.252744407150662, 'clf_report_df':                      0            1  ...            8            9
# precision     0.419355     0.483010  ...     0.454768     0.533183
# recall        0.533000     0.398000  ...     0.372000     0.707000
# f1-score      0.469397     0.436404  ...     0.409241     0.607911
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.41935483870967744, 'recall': 0.533, 'f1-score': 0.469396741523558, 'support': 1000}, '1': {'precision': 0.4830097087378641, 'recall': 0.398, 'f1-score': 0.4364035087719298, 'support': 1000}, '2': {'precision': 0.2903575297941495, 'recall': 0.268, 'f1-score': 0.2787311492459698, 'support': 1000}, '3': {'precision': 0.3439153439153439, 'recall': 0.195, 'f1-score': 0.24888321633694957, 'support': 1000}, '4': {'precision': 0.46258503401360546, 'recall': 0.408, 'f1-score': 0.43358129649309246, 'support': 1000}, '5': {'precision': 0.4086814086814087, 'recall': 0.499, 'f1-score': 0.4493471409275101, 'support': 1000}, '6': {'precision': 0.4849921011058452, 'recall': 0.614, 'f1-score': 0.5419240953221536, 'support': 1000}, '7': {'precision': 0.43237250554323725, 'recall': 0.39, 'f1-score': 0.41009463722397477, 'support': 1000}, '8': {'precision': 0.4547677261613692, 'recall': 0.372, 'f1-score': 0.40924092409240925, 'support': 1000}, '9': {'precision': 0.5331825037707391, 'recall': 0.707, 'f1-score': 0.6079105760963027, 'support': 1000}, 'accuracy': 0.4384, 'macro avg': {'precision': 0.43132187004332395, 'recall': 0.4384, 'f1-score': 0.4285513286033851, 'support': 10000}, 'weighted avg': {'precision': 0.4313218700433239, 'recall': 0.4384, 'f1-score': 0.428551328603385, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0001220703125, class_weight='balanced',
#                            dual=False, max_iter=5000, verbose=2))]), 'test_acc': 0.4171, 'test_ap': 0.2355086130723485, 'clf_report_df':                      0            1  ...            8            9
# precision     0.399552     0.486111  ...     0.497067     0.468768
# recall        0.535000     0.315000  ...     0.339000     0.803000
# f1-score      0.457460     0.382282  ...     0.403092     0.591965
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.39955190440627336, 'recall': 0.535, 'f1-score': 0.4574604531851219, 'support': 1000}, '1': {'precision': 0.4861111111111111, 'recall': 0.315, 'f1-score': 0.3822815533980583, 'support': 1000}, '2': {'precision': 0.27668539325842695, 'recall': 0.197, 'f1-score': 0.23014018691588783, 'support': 1000}, '3': {'precision': 0.37339055793991416, 'recall': 0.087, 'f1-score': 0.1411192214111922, 'support': 1000}, '4': {'precision': 0.49280575539568344, 'recall': 0.274, 'f1-score': 0.35218508997429304, 'support': 1000}, '5': {'precision': 0.38789237668161436, 'recall': 0.519, 'f1-score': 0.4439692044482464, 'support': 1000}, '6': {'precision': 0.3935079726651481, 'recall': 0.691, 'f1-score': 0.5014513788098693, 'support': 1000}, '7': {'precision': 0.40175953079178883, 'recall': 0.411, 'f1-score': 0.4063272367770637, 'support': 1000}, '8': {'precision': 0.4970674486803519, 'recall': 0.339, 'f1-score': 0.4030915576694412, 'support': 1000}, '9': {'precision': 0.46876824284880325, 'recall': 0.803, 'f1-score': 0.5919646148175451, 'support': 1000}, 'accuracy': 0.4171, 'macro avg': {'precision': 0.4177540293779115, 'recall': 0.4171, 'f1-score': 0.39099904974067196, 'support': 10000}, 'weighted avg': {'precision': 0.4177540293779115, 'recall': 0.4171, 'f1-score': 0.3909990497406719, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.002424462017082331, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4384, 'test_ap': 0.252744407150662, 'clf_report_df':                      0            1  ...            8            9
# precision     0.419355     0.483010  ...     0.454768     0.533183
# recall        0.533000     0.398000  ...     0.372000     0.707000
# f1-score      0.469397     0.436404  ...     0.409241     0.607911
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.41935483870967744, 'recall': 0.533, 'f1-score': 0.469396741523558, 'support': 1000}, '1': {'precision': 0.4830097087378641, 'recall': 0.398, 'f1-score': 0.4364035087719298, 'support': 1000}, '2': {'precision': 0.2903575297941495, 'recall': 0.268, 'f1-score': 0.2787311492459698, 'support': 1000}, '3': {'precision': 0.3439153439153439, 'recall': 0.195, 'f1-score': 0.24888321633694957, 'support': 1000}, '4': {'precision': 0.46258503401360546, 'recall': 0.408, 'f1-score': 0.43358129649309246, 'support': 1000}, '5': {'precision': 0.4086814086814087, 'recall': 0.499, 'f1-score': 0.4493471409275101, 'support': 1000}, '6': {'precision': 0.4849921011058452, 'recall': 0.614, 'f1-score': 0.5419240953221536, 'support': 1000}, '7': {'precision': 0.43237250554323725, 'recall': 0.39, 'f1-score': 0.41009463722397477, 'support': 1000}, '8': {'precision': 0.4547677261613692, 'recall': 0.372, 'f1-score': 0.40924092409240925, 'support': 1000}, '9': {'precision': 0.5331825037707391, 'recall': 0.707, 'f1-score': 0.6079105760963027, 'support': 1000}, 'accuracy': 0.4384, 'macro avg': {'precision': 0.43132187004332395, 'recall': 0.4384, 'f1-score': 0.4285513286033851, 'support': 10000}, 'weighted avg': {'precision': 0.4313218700433239, 'recall': 0.4384, 'f1-score': 0.428551328603385, 'support': 10000}}}}}, 96: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.01, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.5002, 'test_ap': 0.30499456894850424, 'clf_report_df':                      0            1  ...            8            9
# precision     0.475189     0.570602  ...     0.536920     0.576087
# recall        0.565000     0.493000  ...     0.509000     0.742000
# f1-score      0.516217     0.528970  ...     0.522587     0.648601
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.4751892346509672, 'recall': 0.565, 'f1-score': 0.5162174508908177, 'support': 1000}, '1': {'precision': 0.5706018518518519, 'recall': 0.493, 'f1-score': 0.5289699570815449, 'support': 1000}, '2': {'precision': 0.35654008438818563, 'recall': 0.338, 'f1-score': 0.3470225872689938, 'support': 1000}, '3': {'precision': 0.39473684210526316, 'recall': 0.315, 'f1-score': 0.3503893214682981, 'support': 1000}, '4': {'precision': 0.4669421487603306, 'recall': 0.452, 'f1-score': 0.4593495934959349, 'support': 1000}, '5': {'precision': 0.48664343786295006, 'recall': 0.419, 'f1-score': 0.4502955400322407, 'support': 1000}, '6': {'precision': 0.5497975708502024, 'recall': 0.679, 'f1-score': 0.6076062639821029, 'support': 1000}, '7': {'precision': 0.5438401775804661, 'recall': 0.49, 'f1-score': 0.5155181483429774, 'support': 1000}, '8': {'precision': 0.5369198312236287, 'recall': 0.509, 'f1-score': 0.5225872689938399, 'support': 1000}, '9': {'precision': 0.5760869565217391, 'recall': 0.742, 'f1-score': 0.6486013986013985, 'support': 1000}, 'accuracy': 0.5002, 'macro avg': {'precision': 0.49572981357955853, 'recall': 0.5002, 'f1-score': 0.4946557530158149, 'support': 10000}, 'weighted avg': {'precision': 0.49572981357955853, 'recall': 0.5002, 'f1-score': 0.49465575301581494, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0009765625, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.4967, 'test_ap': 0.30041490928688913, 'clf_report_df':                      0            1  ...            8            9
# ...
# precision     0.352740     0.417256  ...     0.468549     0.479705
# recall        0.412000     0.295000  ...     0.365000     0.780000
# f1-score      0.380074     0.345636  ...     0.410343     0.594059
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.3527397260273973, 'recall': 0.412, 'f1-score': 0.3800738007380074, 'support': 1000}, '1': {'precision': 0.41725601131541723, 'recall': 0.295, 'f1-score': 0.34563561804335086, 'support': 1000}, '2': {'precision': 0.22901849217638692, 'recall': 0.161, 'f1-score': 0.18907809747504406, 'support': 1000}, '3': {'precision': 0.21747042766151045, 'recall': 0.239, 'f1-score': 0.22772748928060976, 'support': 1000}, '4': {'precision': 0.3099352051835853, 'recall': 0.287, 'f1-score': 0.2980269989615784, 'support': 1000}, '5': {'precision': 0.358974358974359, 'recall': 0.392, 'f1-score': 0.3747609942638624, 'support': 1000}, '6': {'precision': 0.4139834406623735, 'recall': 0.45, 'f1-score': 0.4312410158121706, 'support': 1000}, '7': {'precision': 0.5178351783517835, 'recall': 0.421, 'f1-score': 0.46442360728075016, 'support': 1000}, '8': {'precision': 0.4685494223363286, 'recall': 0.365, 'f1-score': 0.4103428892636312, 'support': 1000}, '9': {'precision': 0.4797047970479705, 'recall': 0.78, 'f1-score': 0.594059405940594, 'support': 1000}, 'accuracy': 0.3802, 'macro avg': {'precision': 0.37654670597371126, 'recall': 0.38020000000000004, 'f1-score': 0.3715369917059599, 'support': 10000}, 'weighted avg': {'precision': 0.37654670597371126, 'recall': 0.3802, 'f1-score': 0.3715369917059599, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.08376776400682924, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.3878, 'test_ap': 0.22275012101955163, 'clf_report_df':                      0            1  ...            8            9
# precision     0.367613     0.431487  ...     0.458286     0.516107
# recall        0.479000     0.296000  ...     0.401000     0.753000
# f1-score      0.415979     0.351127  ...     0.427733     0.612444
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.36761320030698386, 'recall': 0.479, 'f1-score': 0.415979157620495, 'support': 1000}, '1': {'precision': 0.4314868804664723, 'recall': 0.296, 'f1-score': 0.3511269276393832, 'support': 1000}, '2': {'precision': 0.22317596566523606, 'recall': 0.208, 'f1-score': 0.21532091097308487, 'support': 1000}, '3': {'precision': 0.2230769230769231, 'recall': 0.203, 'f1-score': 0.212565445026178, 'support': 1000}, '4': {'precision': 0.3018660812294182, 'recall': 0.275, 'f1-score': 0.28780743066457354, 'support': 1000}, '5': {'precision': 0.3438538205980066, 'recall': 0.414, 'f1-score': 0.37568058076225047, 'support': 1000}, '6': {'precision': 0.45654450261780105, 'recall': 0.436, 'f1-score': 0.44603580562659845, 'support': 1000}, '7': {'precision': 0.5398692810457516, 'recall': 0.413, 'f1-score': 0.4679886685552408, 'support': 1000}, '8': {'precision': 0.4582857142857143, 'recall': 0.401, 'f1-score': 0.42773333333333335, 'support': 1000}, '9': {'precision': 0.5161069225496916, 'recall': 0.753, 'f1-score': 0.6124440829605531, 'support': 1000}, 'accuracy': 0.3878, 'macro avg': {'precision': 0.38618792918419986, 'recall': 0.38780000000000003, 'f1-score': 0.3812682343161691, 'support': 10000}, 'weighted avg': {'precision': 0.38618792918419986, 'recall': 0.3878, 'f1-score': 0.381268234316169, 'support': 10000}}}}}, 32: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.041246263829013564, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4544, 'test_ap': 0.26689767808758535, 'clf_report_df':                      0            1  ...            8            9
# precision     0.449677     0.497850  ...     0.479592     0.593778
# recall        0.487000     0.579000  ...     0.376000     0.668000
# f1-score      0.467595     0.535368  ...     0.421525     0.628706
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.44967682363804246, 'recall': 0.487, 'f1-score': 0.4675948151704272, 'support': 1000}, '1': {'precision': 0.49785038693035255, 'recall': 0.579, 'f1-score': 0.5353675450762829, 'support': 1000}, '2': {'precision': 0.3615477629987908, 'recall': 0.299, 'f1-score': 0.3273125342090859, 'support': 1000}, '3': {'precision': 0.30565167243367936, 'recall': 0.265, 'f1-score': 0.28387787895018746, 'support': 1000}, '4': {'precision': 0.4161073825503356, 'recall': 0.496, 'f1-score': 0.4525547445255474, 'support': 1000}, '5': {'precision': 0.3983548766157462, 'recall': 0.339, 'f1-score': 0.36628849270664504, 'support': 1000}, '6': {'precision': 0.504325259515571, 'recall': 0.583, 'f1-score': 0.5408163265306122, 'support': 1000}, '7': {'precision': 0.47478991596638653, 'recall': 0.452, 'f1-score': 0.4631147540983606, 'support': 1000}, '8': {'precision': 0.47959183673469385, 'recall': 0.376, 'f1-score': 0.42152466367713, 'support': 1000}, '9': {'precision': 0.5937777777777777, 'recall': 0.668, 'f1-score': 0.6287058823529412, 'support': 1000}, 'accuracy': 0.4544, 'macro avg': {'precision': 0.4481673695161376, 'recall': 0.45439999999999997, 'f1-score': 0.448715763729722, 'support': 10000}, 'weighted avg': {'precision': 0.44816736951613756, 'recall': 0.4544, 'f1-score': 0.44871576372972205, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.0009765625, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.4498, 'test_ap': 0.2613163361258735, 'clf_report_df':                      0            1  ...            8            9
# precision     0.438087     0.536489  ...     0.459459     0.536834
# recall        0.513000     0.544000  ...     0.374000     0.736000
# f1-score      0.472593     0.540218  ...     0.412348     0.620835
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.4380871050384287, 'recall': 0.513, 'f1-score': 0.4725932749884846, 'support': 1000}, '1': {'precision': 0.5364891518737672, 'recall': 0.544, 'f1-score': 0.5402184707050645, 'support': 1000}, '2': {'precision': 0.4420289855072464, 'recall': 0.183, 'f1-score': 0.25884016973125884, 'support': 1000}, '3': {'precision': 0.29711375212224106, 'recall': 0.175, 'f1-score': 0.22026431718061673, 'support': 1000}, '4': {'precision': 0.4103419516263553, 'recall': 0.492, 'f1-score': 0.44747612551159616, 'support': 1000}, '5': {'precision': 0.3814064362336114, 'recall': 0.32, 'f1-score': 0.3480152256661229, 'support': 1000}, '6': {'precision': 0.42569759896171316, 'recall': 0.656, 'f1-score': 0.516332152695789, 'support': 1000}, '7': {'precision': 0.4818702290076336, 'recall': 0.505, 'f1-score': 0.4931640625, 'support': 1000}, '8': {'precision': 0.4594594594594595, 'recall': 0.374, 'f1-score': 0.41234840132304296, 'support': 1000}, '9': {'precision': 0.536834427425237, 'recall': 0.736, 'f1-score': 0.6208350906790384, 'support': 1000}, 'accuracy': 0.4498, 'macro avg': {'precision': 0.44093290972556937, 'recall': 0.44980000000000003, 'f1-score': 0.4330087290981014, 'support': 10000}, 'weighted avg': {'precision': 0.4409329097255693, 'recall': 0.4498, 'f1-score': 0.4330087290981014, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.041246263829013564, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.4544, 'test_ap': 0.26689767808758535, 'clf_report_df':                      0            1  ...            8            9
# precision     0.449677     0.497850  ...     0.479592     0.593778
# recall        0.487000     0.579000  ...     0.376000     0.668000
# f1-score      0.467595     0.535368  ...     0.421525     0.628706
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.44967682363804246, 'recall': 0.487, 'f1-score': 0.4675948151704272, 'support': 1000}, '1': {'precision': 0.49785038693035255, 'recall': 0.579, 'f1-score': 0.5353675450762829, 'support': 1000}, '2': {'precision': 0.3615477629987908, 'recall': 0.299, 'f1-score': 0.3273125342090859, 'support': 1000}, '3': {'precision': 0.30565167243367936, 'recall': 0.265, 'f1-score': 0.28387787895018746, 'support': 1000}, '4': {'precision': 0.4161073825503356, 'recall': 0.496, 'f1-score': 0.4525547445255474, 'support': 1000}, '5': {'precision': 0.3983548766157462, 'recall': 0.339, 'f1-score': 0.36628849270664504, 'support': 1000}, '6': {'precision': 0.504325259515571, 'recall': 0.583, 'f1-score': 0.5408163265306122, 'support': 1000}, '7': {'precision': 0.47478991596638653, 'recall': 0.452, 'f1-score': 0.4631147540983606, 'support': 1000}, '8': {'precision': 0.47959183673469385, 'recall': 0.376, 'f1-score': 0.42152466367713, 'support': 1000}, '9': {'precision': 0.5937777777777777, 'recall': 0.668, 'f1-score': 0.6287058823529412, 'support': 1000}, 'accuracy': 0.4544, 'macro avg': {'precision': 0.4481673695161376, 'recall': 0.45439999999999997, 'f1-score': 0.448715763729722, 'support': 10000}, 'weighted avg': {'precision': 0.44816736951613756, 'recall': 0.4544, 'f1-score': 0.44871576372972205, 'support': 10000}}}}}, 96: {'best_model': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.02030917620904739, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.5119, 'test_ap': 0.3183976571704946, 'clf_report_df':                      0            1  ...            8            9
# precision     0.464904     0.571036  ...     0.593644     0.632143
# recall        0.510000     0.623000  ...     0.523000     0.708000
# f1-score      0.486409     0.595887  ...     0.556087     0.667925
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.4649042844120328, 'recall': 0.51, 'f1-score': 0.4864091559370529, 'support': 1000}, '1': {'precision': 0.5710357470210816, 'recall': 0.623, 'f1-score': 0.5958871353419417, 'support': 1000}, '2': {'precision': 0.353515625, 'recall': 0.362, 'f1-score': 0.35770750988142286, 'support': 1000}, '3': {'precision': 0.39384615384615385, 'recall': 0.256, 'f1-score': 0.3103030303030303, 'support': 1000}, '4': {'precision': 0.48590021691973967, 'recall': 0.448, 'f1-score': 0.4661810613943808, 'support': 1000}, '5': {'precision': 0.443327239488117, 'recall': 0.485, 'f1-score': 0.46322827125119387, 'support': 1000}, '6': {'precision': 0.5713058419243986, 'recall': 0.665, 'f1-score': 0.6146025878003697, 'support': 1000}, '7': {'precision': 0.5632183908045977, 'recall': 0.539, 'f1-score': 0.5508431272355647, 'support': 1000}, '8': {'precision': 0.5936435868331441, 'recall': 0.523, 'f1-score': 0.556087187666135, 'support': 1000}, '9': {'precision': 0.6321428571428571, 'recall': 0.708, 'f1-score': 0.6679245283018868, 'support': 1000}, 'accuracy': 0.5119, 'macro avg': {'precision': 0.5072839943392122, 'recall': 0.5119, 'f1-score': 0.5069173595112979, 'support': 10000}, 'weighted avg': {'precision': 0.5072839943392122, 'recall': 0.5119, 'f1-score': 0.5069173595112978, 'support': 10000}}}, 'results': {'SVM': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('SVM',
#                  LinearSVC(C=0.001953125, class_weight='balanced', dual=False,
#                            max_iter=5000, verbose=2))]), 'test_acc': 0.511, 'test_ap': 0.31626248306848115, 'clf_report_df':                      0            1  ...            8            9
# precision     0.457683     0.578699  ...     0.614253     0.607342
# recall        0.557000     0.614000  ...     0.543000     0.761000
# f1-score      0.502481     0.595827  ...     0.576433     0.675544
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.45768282662284304, 'recall': 0.557, 'f1-score': 0.5024808299503833, 'support': 1000}, '1': {'precision': 0.5786993402450519, 'recall': 0.614, 'f1-score': 0.5958272683163512, 'support': 1000}, '2': {'precision': 0.35357917570498915, 'recall': 0.326, 'f1-score': 0.3392299687825182, 'support': 1000}, '3': {'precision': 0.4180672268907563, 'recall': 0.199, 'f1-score': 0.26964769647696474, 'support': 1000}, '4': {'precision': 0.4896373056994819, 'recall': 0.378, 'f1-score': 0.42663656884875845, 'support': 1000}, '5': {'precision': 0.44871794871794873, 'recall': 0.49, 'f1-score': 0.4684512428298279, 'support': 1000}, '6': {'precision': 0.5265998457979953, 'recall': 0.683, 'f1-score': 0.5946887244231606, 'support': 1000}, '7': {'precision': 0.5448343079922028, 'recall': 0.559, 'f1-score': 0.5518262586377098, 'support': 1000}, '8': {'precision': 0.6142533936651584, 'recall': 0.543, 'f1-score': 0.5764331210191083, 'support': 1000}, '9': {'precision': 0.6073423782920989, 'recall': 0.761, 'f1-score': 0.6755437194851309, 'support': 1000}, 'accuracy': 0.511, 'macro avg': {'precision': 0.5039413749628526, 'recall': 0.511, 'f1-score': 0.5000765398769913, 'support': 10000}, 'weighted avg': {'precision': 0.5039413749628526, 'recall': 0.511, 'f1-score': 0.5000765398769914, 'support': 10000}}}, 'LR': {'best_estimator': Pipeline(steps=[('standardize', StandardScaler()),
#                 ('LR',
#                  LogisticRegression(C=0.02030917620904739, max_iter=5000,
#                                     multi_class='multinomial'))]), 'test_acc': 0.5119, 'test_ap': 0.3183976571704946, 'clf_report_df':                      0            1  ...            8            9
# precision     0.464904     0.571036  ...     0.593644     0.632143
# recall        0.510000     0.623000  ...     0.523000     0.708000
# f1-score      0.486409     0.595887  ...     0.556087     0.667925
# support    1000.000000  1000.000000  ...  1000.000000  1000.000000
#
# [4 rows x 10 columns], 'clf_report': {'0': {'precision': 0.4649042844120328, 'recall': 0.51, 'f1-score': 0.4864091559370529, 'support': 1000}, '1': {'precision': 0.5710357470210816, 'recall': 0.623, 'f1-score': 0.5958871353419417, 'support': 1000}, '2': {'precision': 0.353515625, 'recall': 0.362, 'f1-score': 0.35770750988142286, 'support': 1000}, '3': {'precision': 0.39384615384615385, 'recall': 0.256, 'f1-score': 0.3103030303030303, 'support': 1000}, '4': {'precision': 0.48590021691973967, 'recall': 0.448, 'f1-score': 0.4661810613943808, 'support': 1000}, '5': {'precision': 0.443327239488117, 'recall': 0.485, 'f1-score': 0.46322827125119387, 'support': 1000}, '6': {'precision': 0.5713058419243986, 'recall': 0.665, 'f1-score': 0.6146025878003697, 'support': 1000}, '7': {'precision': 0.5632183908045977, 'recall': 0.539, 'f1-score': 0.5508431272355647, 'support': 1000}, '8': {'precision': 0.5936435868331441, 'recall': 0.523, 'f1-score': 0.556087187666135, 'support': 1000}, '9': {'precision': 0.6321428571428571, 'recall': 0.708, 'f1-score': 0.6679245283018868, 'support': 1000}, 'accuracy': 0.5119, 'macro avg': {'precision': 0.5072839943392122, 'recall': 0.5119, 'f1-score': 0.5069173595112979, 'support': 10000}, 'weighted avg': {'precision': 0.5072839943392122, 'recall': 0.5119, 'f1-score': 0.5069173595112978, 'support': 10000}}}}}}}
# CPU times: user 1min 14s, sys: 15.6 s, total: 1min 30s
# Wall time: 49min 6s

# %%
clf_report_df = []

for n in ns:
    for r in range(repeats):
        temp = results[r][n]['best_model']['clf_report_df'].T.reset_index()
        temp['n'] = n
        clf_report_df.append(temp)

clf_report_df = pd.concat(clf_report_df)

# %%
accs = []
aps = []

for i in tlc.results.keys():
    accs.append([tlc.results[i][n]['best_model']['test_acc']*100 for n in tlc.results[i].keys()])
    aps.append([tlc.results[i][n]['best_model']['test_ap']*100 for n in tlc.results[i].keys()])

# %%
results_df_accs = pd.DataFrame([j for i in [list(zip(ns,i)) for i in accs] for j in i],
              columns = ['num_labeled_sampled','acc'])

results_df_maps = pd.DataFrame([j for i in [list(zip(ns,i)) for i in aps] for j in i],
              columns = ['num_labeled_sampled','mAP'])

# %%
ax = sns.lineplot(x='num_labeled_sampled',y='acc',marker='o',data=results_df_accs)
ax.set_xscale('log',basex=2)
